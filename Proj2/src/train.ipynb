# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !ls '/content/gdrive/My Drive'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
#  AIAD			   'MIB - EDA'
# 'Android Udacity Lessons'   MIEEC
#  Backup			    object_recognition.ipynb
#  CMOV			    porto-dataset
#  code.zip		    porto-dataset-2
# 'Colab Notebooks'	   'Profs Preferidos.gsheet'
#  CPRO			   'Programação de Computadores'
#  ESINF			    RVAU
#  FEUP.zip		    SDIS
#  image_recognition.ipynb    SETR
# 'ISEP - APROG'		    SIGCHIExtendedAbstractsFormat.docx.gdoc
#  LPOO			    SINF
#  LPOO_PROJ_2.7z		    TVVS
# ...

# %%
# !rm -r keras-retinanet
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# rm: cannot remove 'keras-retinanet': No such file or directory
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4654 (delta 0), reused 0 (delta 0), pack-reused 4651
# Receiving objects: 100% (4654/4654), 12.69 MiB | 6.79 MiB/s, done.
# Resolving deltas: 100% (3108/3108), done.

# %%
# %cd keras-retinanet 
# !pip install . --user
# !python setup.py build_ext --inplace
# Out:
# /content/keras-retinanet
# Processing /content/keras-retinanet
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/b2/9f/57/cb0305f6f5a41fc3c11ad67b8cedfbe9127775b563337827ba
# done
#   Stored in directory: /root/.cache/pip/wheels/80/dd/ac/842235b63dddac12faa4b48ebe58b8944e8c2e57c2e38dddb6
# Successfully built keras-retinanet keras-resnet
# ...
#   The scripts retinanet-convert-model, retinanet-debug, retinanet-evaluate and retinanet-train are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/keras-retinanet/keras_retinanet/utils/compute_overlap.pyx
# ...

# %%
# %cd /content
# !ls -l 

# !python keras-retinanet/keras_retinanet/bin/train.py --epochs=10 --steps=700 csv 'gdrive/My Drive/VCOM/annotations.csv' 'gdrive/My Drive/VCOM/classes.csv'
# Out:
# /content
# total 20
# drwx------ 3 root root 4096 Jan  9 02:18 gdrive
# drwxr-xr-x 9 root root 4096 Jan  9 02:19 keras-retinanet
# drwxr-xr-x 2 root root 4096 Jan  9 02:38 logs
# drwxr-xr-x 1 root root 4096 Jan  3 17:15 sample_data
# drwxr-xr-x 2 root root 4096 Jan  9 02:43 snapshots
# Using TensorFlow backend.
# 2019-01-09 02:53:29.994019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-09 02:53:29.994605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-01-09 02:53:29.994652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# ...

# %%
# %cd /content
# !python keras-retinanet/keras_retinanet/bin/convert_model.py 'gdrive/My Drive/VCOM/resnet50_csv_10.h5' 'gdrive/My Drive/VCOM/inference_model_10.h5'
# Out:
# /content
# Using TensorFlow backend.
# 2019-01-09 07:38:12.717590: E tensorflow/stream_executor/cuda/cuda_driver.cc:300] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2019-01-09 07:38:12.717683: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] retrieving CUDA diagnostic information for host: a5327381fd4b
# 2019-01-09 07:38:12.717712: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:170] hostname: a5327381fd4b
# 2019-01-09 07:38:12.717773: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:194] libcuda reported version is: 396.44.0
# 2019-01-09 07:38:12.717839: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:198] kernel reported version is: 396.44.0
# 2019-01-09 07:38:12.717865: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:305] kernel version seems to match DSO: 396.44.0

# %%
# !mv 'snapshots/resnet50_csv_10.h5' 'gdrive/My Drive/VCOM'
